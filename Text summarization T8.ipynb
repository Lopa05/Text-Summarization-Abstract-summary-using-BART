# %%
pip install transformers torch datasets rouge-score nltk ipywidgets
# Out:
# Requirement already satisfied: transformers in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (4.49.0)
# Requirement already satisfied: torch in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (2.6.0)
# Requirement already satisfied: datasets in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (3.3.2)
# Requirement already satisfied: rouge-score in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (0.1.2)
# Requirement already satisfied: nltk in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (3.9.1)
# Requirement already satisfied: ipywidgets in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (8.1.5)
# Requirement already satisfied: filelock in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.29.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from torch) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from datasets) (3.8.4)
# Requirement already satisfied: absl-py in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from rouge-score) (2.1.0)
# Requirement already satisfied: six>=1.14.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipywidgets) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: colorama in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\lopa\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lopa\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\lopa\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\lopa\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\lopa\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lopa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from transformers import BartTokenizer, BartForConditionalGeneration
import nltk
from nltk.tokenize import sent_tokenize
from rouge_score import rouge_scorer
from datasets import load_dataset
import re
import ipywidgets as widgets

try:
    try:
        nltk.data.find('tokenizers/punkt')
        print("Punkt data already available.")
    except LookupError:
        print("Punkt data not found. Downloading now...")
        nltk.download('punkt')
        nltk.data.find('tokenizers/punkt')
        print("Punkt data downloaded successfully.")
except Exception as e:
    print(f"Failed to download NLTK punkt data: {e}")
    print("Please run 'import nltk; nltk.download('punkt')' manually in a new cell and try again.")
    raise

# Loading pre-trained BART model and tokenizer
model_name = "facebook/bart-large-cnn"
try:
    tokenizer = BartTokenizer.from_pretrained(model_name)
    model = BartForConditionalGeneration.from_pretrained(model_name)
except Exception as e:
    print(f"Error loading BART model: {e}")
    raise

# Loading CNN/DailyMail dataset
try:
    dataset = load_dataset("cnn_dailymail", "3.0.0")
    test_samples = dataset["test"].select(range(3))
except Exception as e:
    print(f"Error loading CNN/DailyMail dataset: {e}")
    raise

# Simple text preprocessing function
def preprocess_text(text):
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Summarization function using BART (abstractive)
def summarize_text(text, max_length=150, min_length=30):
    clean_text = preprocess_text(text)
    inputs = tokenizer(clean_text, max_length=1024, truncation=True, return_tensors="pt")
    summary_ids = model.generate(
        inputs["input_ids"],
        max_length=max_length,
        min_length=min_length,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary



# Evaluate summary using ROUGE
def evaluate_summary(generated_summary, reference_summary):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference_summary, generated_summary)
    return scores

# Test summarization on CNN/DailyMail samples
def test_on_dataset():
    print("Testing Summarization on CNN/DailyMail Dataset Samples:\n")
    for i, sample in enumerate(test_samples):
        article = sample["article"]
        reference_summary = sample["highlights"]
        
        print(f"Sample {i+1}:")
        print("Original Article (first 200 chars):", article[:200], "...")
        print("Reference Summary:", reference_summary)
        
        abstractive = summarize_text(article)
        print("\nAbstractive Summary (BART):", abstractive)
        
        
        print("\nROUGE Scores for Abstractive Summary:")
        rouge_scores = evaluate_summary(abstractive, reference_summary)
        for metric, score in rouge_scores.items():
            print(f"{metric}: Precision={score.precision:.2f}, Recall={score.recall:.2f}, F1={score.fmeasure:.2f}")
        print("-" * 50)

try:
    test_on_dataset()
except Exception as e:
    print(f"Error during dataset testing: {e}")
# Out:
# Punkt data already available.
# Testing Summarization on CNN/DailyMail Dataset Samples:
#
# Sample 1:
# Original Article (first 200 chars): (CNN)The Palestinian Authority officially became the 123rd member of the International Criminal Court on Wednesday, a step that gives the court jurisdiction over alleged crimes in Palestinian territor ...
# Reference Summary: Membership gives the ICC jurisdiction over alleged crimes committed in Palestinian territories since last June .
# Israel and the United States opposed the move, which could open the door to war crimes investigations against Israelis .
#
# Abstractive Summary (BART): The Palestinian Authority becomes the 123rd member of the International Criminal Court. The move gives the court jurisdiction over alleged crimes in Palestinian territories. Israel and the United States opposed the Palestinians' efforts to join the body.
#
# ROUGE Scores for Abstractive Summary:
# rouge1: Precision=0.51, Recall=0.56, F1=0.54
# rouge2: Precision=0.36, Recall=0.39, F1=0.38
# rougeL: Precision=0.46, Recall=0.50, F1=0.48
# --------------------------------------------------
# Sample 2:
# Original Article (first 200 chars): (CNN)Never mind cats having nine lives. A stray pooch in Washington State has used up at least three of her own after being hit by a car, apparently whacked on the head with a hammer in a misguided me ...
# Reference Summary: Theia, a bully breed mix, was apparently hit by a car, whacked with a hammer and buried in a field .
# "She's a true miracle dog and she deserves a good life," says Sara Mellado, who is looking for a home for Theia .
#
# Abstractive Summary (BART): Theia, a one-year-old bully breed mix, was hit by a car and buried in a field. Four days after her apparent death, the dog managed to stagger to a nearby farm. She suffered a dislocated jaw, leg injuries and a caved-in sinus cavity. She still requires surgery to help her breathe.
#
# ROUGE Scores for Abstractive Summary:
# rouge1: Precision=0.43, Recall=0.53, F1=0.47
# rouge2: Precision=0.21, Recall=0.26, F1=0.23
# rougeL: Precision=0.35, Recall=0.44, F1=0.39
# --------------------------------------------------
# Sample 3:
# Original Article (first 200 chars): (CNN)If you've been following the news lately, there are certain things you doubtless know about Mohammad Javad Zarif. He is, of course, the Iranian foreign minister. He has been U.S. Secretary of Sta ...
# Reference Summary: Mohammad Javad Zarif has spent more time with John Kerry than any other foreign minister .
# He once participated in a takeover of the Iranian Consulate in San Francisco .
# The Iranian foreign minister tweets in English .
#
# Abstractive Summary (BART): Mohammad Javad Zarif is the Iranian foreign minister. He has been John Kerry's opposite number in securing a breakthrough in nuclear discussions. But there are some facts about him that are less well-known.
#
# ROUGE Scores for Abstractive Summary:
# rouge1: Precision=0.40, Recall=0.40, F1=0.40
# rouge2: Precision=0.21, Recall=0.21, F1=0.21
# rougeL: Precision=0.26, Recall=0.26, F1=0.26
# --------------------------------------------------
